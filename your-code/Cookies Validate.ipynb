# %%
# Set the graphs as interactive.
# %matplotlib inline
# Import necessary libraries for initial analysis
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as color

from scipy import stats
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
cookies_validate = pd.read_csv("../data/cookies_validate.csv")
cookies_validate.drop(columns=["id", "diameter"], inplace=True)

# %%
cookies_validate.head()
# Out:
#    sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 0                  0.62        19.25      400.0        41.0     172.0
# 1                  0.35         1.00      520.0        35.0     146.0
# 2                  0.39        10.40      440.0        20.0     142.0
# 3                  0.33         1.10      570.0        21.0      82.0
# 4                  0.37        13.50      600.0        52.0     192.0
#
#    density    pH  grams baking soda  bake time  quality butter type  weight  \
# 0   1.0002  7.98               0.67        9.7        0      melted    16.6
# 1   0.9930  8.45               0.44       10.0        0      melted    13.8
# 2   0.9974  8.20               0.53       10.0        0      melted    17.0
# 3   0.9910  8.32               0.46       10.9        0      melted    12.4
# 4   0.9975  8.00               0.44        9.1        0      melted    14.8
#
#             mixins  crunch factor  aesthetic appeal
# 0  nuts, chocolate           1.85                 3
# 1        chocolate           1.43                 3
# 2        chocolate           1.57                 3
# 3  chocolate, oats           1.44                 3
# 4        chocolate           1.51                 3

# %%
# we observe that mixins there's a not space applied in 'nuts,raisins', then we replace with space
cookies_validate["mixins"] = cookies_validate["mixins"].str.replace("nuts,raisins", "nuts, raisins")

# %% [markdown]
# # Pre-processing categorical features

# %% [markdown]
# ### One Hot Encoding

# %%
cookies_validate = pd.concat([cookies_validate,pd.get_dummies(cookies_validate['butter type'], prefix='butter type')],axis=1)
cookies_validate.drop(['butter type'],axis=1, inplace=True)

# %% [markdown]
# ### Ordinal Encoding

# %%
cookies_validate['mixins'] = cookies_validate['mixins'].astype('category')
cookies_validate['mixins'] = cookies_validate['mixins'].cat.codes

# %%
cookies_validate[cookies_validate["bake temp"] > 1000]
# Out:
#      sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 190                  0.54         1.40     1570.0        34.0     132.0
# 193                  0.52         1.30     1480.0        45.0     149.0
# 303                  0.37        10.00     1690.0        22.0     210.0
# 330                  0.38        13.10     1120.0        14.0      94.0
# 349                  1.00         1.10     1540.0        46.0     114.0
# 469                  0.20         5.70     1180.0        61.0     172.0
# 523                  0.38         2.80     1440.0        12.0      65.0
# 530                  0.36         6.70     1850.0        51.5     151.0
# 555                  0.27        10.70     1100.0        20.0     103.0
# 595                  0.23         8.90     1050.0        22.0     155.0
# 687                  0.50         1.00     1270.0        63.0     178.0
# 706                  0.18         3.80     1760.0        52.0     145.0
# 714                  0.16         2.00     1010.0        13.0      49.0
# 718                  0.50         4.50     1070.0         5.0      13.0
# 723                  0.66         2.95     1160.0        12.0      29.0
# 724                  0.61         2.00     1120.0        13.0      95.0
# 726                  0.58         3.70     1740.0         6.0      16.0
# 748                  0.36         2.80     1160.0        26.0      55.0
# 758                  0.12         1.80     1780.0         6.0      21.0
# 766                  0.00         2.70     1230.0        15.0      33.0
# 772                  0.37        15.40     2140.0        55.0      95.0
# 778                  0.50        13.80     2050.0        48.0      82.0
#
#      density    pH  grams baking soda  bake time  quality  weight  mixins  \
# 190  0.99449  8.11               0.53        9.0        0    14.4       9
# 193  0.99468  8.08               0.56        8.7        0    14.2       4
# 303  0.99776  8.02               0.64        9.5        0    15.4       4
# 330  0.99792  8.02               0.48        9.2        0    13.8       9
# 349  0.99310  7.95               0.43        9.2        0    14.4       0
# 469  0.99460  8.24               0.43        9.5        0    12.8       9
# 523  0.99080  7.95               0.64       11.4        0    12.2       0
# 530  0.99528  8.17               0.42        9.3        0    13.0       9
# 555  0.99672  8.08               0.41        9.0        0    13.2       4
# 595  0.99692  8.01               0.58        9.5        0    14.4       9
# 687  0.99212  8.10               0.45        9.7        0    11.6       9
# 706  0.99860  8.16               0.88        9.2        0    17.8       6
# 714  0.99620  8.14               0.57       11.0        0    17.4       6
# 718  0.99800  8.28               0.83       11.5        0    20.6       4
# 723  0.99700  8.24               0.75       11.7        0    21.0       4
# 724  0.99700  8.16               0.54        9.1        0    16.8       6
# 726  0.99700  8.19               0.70       11.3        0    20.8       9
# 748  0.99722  8.18               0.68       10.9        0    19.2       7
# 758  0.99600  8.28               0.87        9.8        0    15.6       7
# 766  0.99538  8.44               0.63       11.3        0    13.6       6
# 772  1.00369  8.18               0.77        9.0        0    20.4       7
# 778  1.00242  8.16               0.75        8.8        0    19.8       7
#
#      crunch factor  aesthetic appeal  butter type_cubed  butter type_melted
# 190           1.30                 3                  0                   1
# 193           1.42                 3                  0                   1
# 303           1.16                 3                  0                   1
# 330           1.80                 3                  0                   1
# 349           1.62                 3                  0                   1
# 469           1.59                 3                  0                   1
# 523           1.16                 3                  0                   1
# 530           1.01                 3                  0                   1
# 555           1.74                 3                  0                   1
# 595           1.93                 3                  0                   1
# 687           1.82                 3                  0                   1
# 706           1.46                 3                  1                   0
# 714           1.28                 3                  1                   0
# 718           1.03                 3                  1                   0
# 723           1.32                 3                  1                   0
# 724           1.76                 3                  1                   0
# 726           1.32                 3                  1                   0
# 748           1.44                 3                  1                   0
# 758           1.49                 3                  1                   0
# 766           1.24                 3                  1                   0
# 772           1.00                 3                  1                   0
# 778           1.90                 3                  1                   0

# %%
cookies_validate
# Out:
#      sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 0                    0.62        19.25      400.0        41.0     172.0
# 1                    0.35         1.00      520.0        35.0     146.0
# 2                    0.39        10.40      440.0        20.0     142.0
# 3                    0.33         1.10      570.0        21.0      82.0
# 4                    0.37        13.50      600.0        52.0     192.0
# ..                    ...          ...        ...         ...       ...
# 774                  0.02         1.90      780.0        18.0      30.0
# 775                  0.19         5.20      940.0        19.0      98.0
# 776                  0.00         2.10      600.0         6.0      13.0
# 777                  0.08         2.30      670.0        19.0      32.0
# 778                  0.50        13.80     2050.0        48.0      82.0
#
#      density    pH  grams baking soda  bake time  quality  weight  mixins  \
# 0    1.00020  7.98               0.67        9.7        0    16.6       4
# 1    0.99300  8.45               0.44       10.0        0    13.8       0
# 2    0.99740  8.20               0.53       10.0        0    17.0       0
# 3    0.99100  8.32               0.46       10.9        0    12.4       1
# 4    0.99750  8.00               0.44        9.1        0    14.8       0
# ..       ...   ...                ...        ...      ...     ...     ...
# 774  0.99712  8.40               0.75        9.8        0    13.8       6
# 775  0.99713  8.16               0.52        9.6        0    14.8       5
# 776  0.99664  8.59               0.61       10.0        0    12.4       5
# 777  0.99648  8.52               0.57       11.0        0    13.4       8
# 778  1.00242  8.16               0.75        8.8        0    19.8       7
#
#      crunch factor  aesthetic appeal  butter type_cubed  butter type_melted
# 0             1.85                 3                  0                   1
# 1             1.43                 3                  0                   1
# 2             1.57                 3                  0                   1
# 3             1.44                 3                  0                   1
# 4             1.51                 3                  0                   1
# ..             ...               ...                ...                 ...
# 774           1.01                 3                  1                   0
# 775           1.68                 3                  1                   0
# 776           1.38                 3                  1                   0
# 777           1.63                 3                  1                   0
# 778           1.90                 3                  1                   0
#
# [779 rows x 16 columns]
